# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Dataset.csv")

# %%
df
# Out:
#      Crop  Sampling date  Plot No. Irrigation Status Treatments  Trmt No.  \
# 0     Rice     13-Jun-08       221                BI    ZT_R_25         4
# 1     Rice     13-Jun-08       221                BI    ZT_R_25         4
# 2     Rice     13-Jun-08       221                BI    ZT_R_25         4
# 3     Rice     13-Jun-08       221                BI    ZT_R_25         4
# 4     Rice     13-Jun-08       221                BI    ZT_R_25         4
# ...    ...           ...       ...               ...        ...       ...
# 6077  Rice     14-Jul-09       340                BI  CT_FP_AWD         8
# 6078  Rice     14-Jul-09       340                BI  CT_FP_AWD         8
# 6079  Rice     14-Jul-09       340                BI  CT_FP_AWD         8
# 6080  Rice     14-Jul-09       340                BI  CT_FP_AWD         8
# 6081  Rice     14-Jul-09       340                BI  CT_FP_AWD         8
#
#       Tillage  Residue  Irrigation  Soil depth (cm)  Ece (dS/m)
# ...

# %%
df1=pd.get_dummies(df['Irrigation'])
df2=pd.concat([df1,df],axis=1)

# %%
df2
# Out:
#       1  2  3 Crop  Sampling date  Plot No. Irrigation Status Treatments  \
# 0     1  0  0  Rice     13-Jun-08       221                BI    ZT_R_25
# 1     1  0  0  Rice     13-Jun-08       221                BI    ZT_R_25
# 2     1  0  0  Rice     13-Jun-08       221                BI    ZT_R_25
# 3     1  0  0  Rice     13-Jun-08       221                BI    ZT_R_25
# 4     1  0  0  Rice     13-Jun-08       221                BI    ZT_R_25
# ...  .. .. ..   ...           ...       ...               ...        ...
# 6077  0  0  1  Rice     14-Jul-09       340                BI  CT_FP_AWD
# 6078  0  0  1  Rice     14-Jul-09       340                BI  CT_FP_AWD
# 6079  0  0  1  Rice     14-Jul-09       340                BI  CT_FP_AWD
# 6080  0  0  1  Rice     14-Jul-09       340                BI  CT_FP_AWD
# 6081  0  0  1  Rice     14-Jul-09       340                BI  CT_FP_AWD
#
#       Trmt No.  Tillage  Residue  Irrigation  Soil depth (cm)  Ece (dS/m)
# ...
